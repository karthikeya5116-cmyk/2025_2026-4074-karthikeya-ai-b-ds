# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikeya5116-cmyk/2025_2026-4074-karthikeya-ai-b-ds/blob/main/plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#plotting
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[2,3,4,8,10]
plt.plot(x,y)
plt.xlabel('xvalues')
plt.ylabel('yvalues')
plt.title('x-y greph')
plt.show()
