# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikeya5116-cmyk/2025_2026-4074-karthikeya-ai-b-ds/blob/main/Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# DICTIONARY OPERATIONS

# Creating a dictionary
d = {
    "name": "Manasvi.I",
    "age": 19,
    "course": "BTech"
}
print("Original dictionary:", d)

# Accessing values
print("Name:", d["name"])
print("Age:", d.get("age"))

# Adding a new key-value pair
d["college"] = "OU"
print("After adding:", d)

# Updating value
d["age"] = 21
print("After updating:", d)

# Removing elements
d.pop("course")
print("After pop:", d)

removed_item = d.popitem()
print("After popitem:", d)
print("Removed item:", removed_item)

# Keys, values, items
print("Keys:", d.keys())
print("Values:", d.values())
print("Items:", d.items())

# Membership
print("Is 'name' a key?", "name" in d)

# Length
print("Length of dictionary:", len(d))

# Looping through dictionary
print("Looping through keys:")
for key in d:
    print(key, ":", d[key])

print("Looping through key-value pairs:")
for k, v in d.items():
    print(k, "->", v)

# Copying dictionary
d_copy = d.copy()
print("Copied dictionary:", d_copy)

# Updating using update()
d.update({"city": "Nanded", "age": 23})
print("After update():", d)

# Nested dictionary
student = {
    "id": 1,
    "info": {
        "name": "ruthu",
        "marks": 90
    }
}
print("Nested dictionary value:", student["info"]["marks"])

# Clearing dictionary
d.clear()
print("After clear:", d)
# Out:
# Original dictionary: {'name': 'Manasvi.I', 'age': 19, 'course': 'BTech'}
# Name: Manasvi.I
# Age: 19
# After adding: {'name': 'Manasvi.I', 'age': 19, 'course': 'BTech', 'college': 'OU'}
# After updating: {'name': 'Manasvi.I', 'age': 21, 'course': 'BTech', 'college': 'OU'}
# After pop: {'name': 'Manasvi.I', 'age': 21, 'college': 'OU'}
# After popitem: {'name': 'Manasvi.I', 'age': 21}
# Removed item: ('college', 'OU')
# Keys: dict_keys(['name', 'age'])
# Values: dict_values(['Manasvi.I', 21])
# Items: dict_items([('name', 'Manasvi.I'), ('age', 21)])
# Is 'name' a key? True
# Length of dictionary: 2
# Looping through keys:
# name : Manasvi.I
# age : 21
# Looping through key-value pairs:
# name -> Manasvi.I
# age -> 21
# Copied dictionary: {'name': 'Manasvi.I', 'age': 21}
# After update(): {'name': 'Manasvi.I', 'age': 23, 'city': 'Nanded'}
# Nested dictionary value: 90
# After clear: {}
