# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikeya5116-cmyk/2025_2026-4074-karthikeya-ai-b-ds/blob/main/descriptive_statistic_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#descriptive statistic function
import pandas as pd
data={
    "age":[22,25,47,35,46,50,28,33,39,41],
    "salary":[3000,3200,5500,4000,5200,6000,3500,3700,4500,4800]
}
df=pd.DataFrame(data)
print("Summary Statistics:")
print("mean:",df.mean())
print("median:",df.median())
print("mode:",df.mode())
print("\n minimum value:",df.min())
print("\n maximum value:",df.max())
print("\n standard deviation",df.std())
print("\n variance:",df.var())
print("\n count:",df.count())
print("\n skewness:",df.skew())
print("\n kurtosis:",df.kurt())
# Out:
# Summary Statistics:
# mean: age         36.6
# salary    4340.0
# dtype: float64
# median: age         37.0
# salary    4250.0
# dtype: float64
# mode:    age  salary
# 0   22    3000
# 1   25    3200
# 2   28    3500
# 3   33    3700
# 4   35    4000
# 5   39    4500
# 6   41    4800
# 7   46    5200
# 8   47    5500
# 9   50    6000
#
#  minimum value: age         22
# salary    3000
# dtype: int64
#
#  maximum value: age         50
# salary    6000
# dtype: int64
#
#  standard deviation age          9.651713
# salary    1022.198067
# dtype: float64
#
#  variance: age       9.315556e+01
# salary    1.044889e+06
# dtype: float64
#
#  count: age       10
# salary    10
# dtype: int64
#
#  skewness: age      -0.138915
# salary    0.271889
# dtype: float64
#
#  kurtosis: age      -1.287437
# salary   -1.223068
# dtype: float64
