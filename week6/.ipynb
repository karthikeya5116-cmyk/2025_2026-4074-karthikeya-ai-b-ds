# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikeya5116-cmyk/2025_2026-4074-karthikeya-ai-b-ds/blob/main/week6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#23 linear regression on any sample dataset
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
x = np.array([[1],[2],[3],[4],[5]])
y = np.array([2,3,4,5,6])
model = LinearRegression()
model.fit(x, y)
y_pred = model.predict(x)
print("slope (m):", model.coef_[0])
print("inteircept (b):", model.intercept_)
plt.scatter(x, y, color='blue', label="Actual")
plt.plot(x, y_pred, color='red', label="Regression line")
plt.legend()
plt.show()
# Out:
# slope (m): 1.0
# inteircept (b): 1.0
