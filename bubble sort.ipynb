# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikeya5116-cmyk/2025_2026-4074-karthikeya-ai-b-ds/blob/main/bubble%20sort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#bubble sort
n = int(input("Enter number of elements: "))

arr = []

for i in range(n):
    arr.append(int(input(f"Enter element {i+1}: ")))

print("\nOriginal array:", arr)

# Bubble sort logic
for i in range(n - 1):
    for j in range(n - 1 - i):
        if arr[j] > arr[j + 1]:
            # Swap
            arr[j], arr[j + 1] = arr[j + 1], arr[j]

print("Sorted array:", arr)
# Out:
# Enter number of elements: 5
# Enter element 1: 6
# Enter element 2: 3
# Enter element 3: 2
# Enter element 4: 1
# Enter element 5: 4
#
# Original array: [6, 3, 2, 1, 4]
# Sorted array: [1, 2, 3, 4, 6]
