# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikeya5116-cmyk/2025_2026-4074-karthikeya-ai-b-ds/blob/main/binary%20search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Enter number of elements: "))
arr = []

# Taking array elements from user
for i in range(n):
    value = int(input(f"Enter element {i+1}: "))
    arr.append(value)

# Binary search needs sorted array
arr.sort()
print("Sorted array:", arr)

key = int(input("Enter element to search: "))

low = 0
high = n - 1
found = False

# Binary search
while low <= high:
    mid = (low + high) // 2

    if arr[mid] == key:
        print("Element found at index", mid)
        found = True
        break
    elif arr[mid] < key:
        low = mid + 1
    else:
        high = mid - 1

if not found:
    print("Element not found")
# Out:
# Enter number of elements: 8
# Enter element 1: 2
# Enter element 2: 5
# Enter element 3: 4
# Enter element 4: 6
# Enter element 5: 7
# Enter element 6: 6
# Enter element 7: 6
# Enter element 8: 9
# Sorted array: [2, 4, 5, 6, 6, 6, 7, 9]
# Enter element to search: 2
# Element found at index 0
